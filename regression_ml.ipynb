# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvadesai1/Datasets-Regressions/blob/main/regression_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Simple Linear Regression**
#
# ---

# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Importing the Dataset**

# %%
df = pd.read_csv('/content/Salary_dataset.csv')
X = df.iloc[:,1:-1].values
Y = df.iloc[:,-1].values

# %% [markdown]
# ## **Splitting the Dataset into Train and Test Set**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2, random_state=0)

# %% [markdown]
# ## **Training the Simple Linear Regression model on the Training set**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## **Predicting the Test set results**

# %%
Y_pred = regressor.predict(X_test)

# %% [markdown]
# ## **Visualising the Training set**

# %%
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train, regressor.predict(X_train), color='black')
plt.title('Salary vs Experience (Training set)')
plt.xlabel("Age of a person")
plt.ylabel("Expected Salary")
plt.show()

# %% [markdown]
# ## **Visualising the Test set results**

# %%
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_test, Y_pred, color='black')
plt.title('Salary vs Experience (Training set)')
plt.xlabel("Age of a person")
plt.ylabel("Expected Salary")
plt.show()

# %% [markdown]
# # **Multiple Linear Regression**
#
# ---

# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Importing the Dataset**

# %%
df1 = pd.read_csv('/content/House_price.csv')
df1.drop("Address",axis=1, inplace=True)
x = df1.iloc[:,:-1].values
y = df1.iloc[:,-1].values

# %% [markdown]
# ## **Splitting Data into Train and Test sets**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size= 0.2, random_state=0)
# Out:
# array([ 302355.836 , 1026126.584 , 1492965.733 , ..., 1202992.884 ,
#         842985.8529, 1571253.531 ])

# %% [markdown]
# ## **Training the Multiple Linear Regression model on the Training set**

# %%
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression()
regressor1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## **Predicting the Test set results**

# %%
y_pred = regressor1.predict(x_test)
np.set_printoptions(precision=2) 
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[1549091.42 1599478.99]
#  [ 854843.89  869026.58]
#  [ 934459.76  911202.17]
#  ...
#  [1214218.76 1276987.49]
#  [1051720.58 1011331.16]
#  [ 897353.68  940229.23]]

# %% [markdown]
# ## **Visualizing the Training Set**

# %%
plt.scatter(x_train[:,0],y_train,color='green')
plt.plot(x_train[:,0], regressor1.predict(x_train), color='blue')
plt.xlabel('Avg. Area Income')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()

# %%
plt.scatter(x_train[:,1],y_train,color='green')
plt.plot(x_train[:,1], regressor1.predict(x_train), color='blue')
plt.xlabel('House Age')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()

# %%
plt.scatter(x_train[:,2],y_train,color='green')
plt.plot(x_train[:,2], regressor1.predict(x_train), color='blue')
plt.xlabel('Number of Rooms')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()

# %%
plt.scatter(x_train[:,3],y_train,color='green')
plt.plot(x_train[:,3], regressor1.predict(x_train), color='blue')
plt.xlabel('Number of Bedooms')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()

# %%
plt.scatter(x_train[:,4],y_train,color='green')
plt.plot(x_train[:,4], regressor1.predict(x_train), color='blue')
plt.xlabel('Area Population')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()

# %% [markdown]
# ## **Visualizing the Test Set Result**

# %%
plt.scatter(x_test[:,0],y_test,color='green')
plt.plot(x_test[:,0], regressor1.predict(x_test), color='blue')
plt.xlabel('Avg. Area Income')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()

# %%
plt.scatter(x_test[:,0],y_test,color='green')
plt.plot(x_test[:,0], regressor1.predict(x_test), color='blue')
plt.xlabel('House Age')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()

# %%
plt.scatter(x_test[:,0],y_test,color='green')
plt.plot(x_test[:,0], regressor1.predict(x_test), color='blue')
plt.xlabel('Number of Rooms')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()

# %%
plt.scatter(x_test[:,0],y_test,color='green')
plt.plot(x_test[:,0], regressor1.predict(x_test), color='blue')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()

# %%
plt.scatter(x_test[:,0],y_test,color='green')
plt.plot(x_test[:,0], regressor1.predict(x_test), color='blue')
plt.xlabel('Area Population')
plt.ylabel('Price')
plt.title('House Price Prediction')
plt.show()
